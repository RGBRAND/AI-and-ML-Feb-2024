# %%
#seabon 
#matplot lib
#

# %% [markdown]
# Regression Algorithm
# -Linear Regression ('sklearn.linear_model')
#     -Simple linear Regression
#     -multiple linear Regression
#     -Polynomial Regression
# -Decision Tree Regression ('sklearn.tree')
# -Random Forest Regression ('skelarn.ensemble')
# -Support Vector Regression ('sklearn.svm')
# -Gaussion process Regression
# -Gradient Boosting Regression ('sklearn.ensemble')

# %% [markdown]
# -Linaer Regression

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
url = 'https://raw.githubusercontent.com/digipodium/Datasets/main/regression/Salary_Data.csv'
df = pd.read_csv(url)
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
df.plot(x='YearsExperience', y='Salary', style='o')
plt.show()

# %%
from sklearn.linear_model import LinearRegression 
from sklearn.model_selection import train_test_split

# %%
X = df[['YearsExperience']] #2D matrix (datafreame)
y = df['Salary'] #1D array (series)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
print(X_train.shape, y_train.shape) #just for testing the result 
print(X_test.shape, y_test.shape)
# Out:
# (21, 1) (21,)
# (9, 1) (9,)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

y_pred = model.predict(X_test) 
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
acc = r2_score(y_test, y_pred)


print(f'MSE: {mse: .1f}')
print(f'MAE: {mae: .1f}')
print(f'Accuracy: {acc*100: .1f}')
# Out:
# MSE:  18906271.3
# MAE:  3437.1
# Accuracy:  96.7

# %%
plt.title('Linear Regession Test Result')
plt.scatter(X_test, y_test, color='gray', label='Actual')
plt.plot(X_test, y_pred, color='red', linewidth=2, label='Predicted')
plt.legend()
plt.text(4, 110000, f'Accuracy: {acc*100: .1f}%', bbox={'edgecolor': 'red'})
# Out:
# Text(4, 110000, 'Accuracy:  96.7%')
